# %%
import tensorflow as tf
import numpy as np

# %%
# mount Google Drive
from google.colab import drive
drive.mount('/content/gdrive')

# unzip
import zipfile, os, shutil

dataset = '/content/gdrive/My Drive/Colab_Notebooks/DL/datasets/cifar10.zip'
dst_path = '/content/cifa10'
dst_file = os.path.join(dst_path, 'cifar10.zip')

if not os.path.exists(dst_path):
  os.makedirs(dst_path)

# copy zip file
shutil.copy(dataset, dst_file)
  
with zipfile.ZipFile(dst_file, 'r') as file:
  file.extractall(dst_path)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
train_dir = os.path.join(dst_path, 'cifar10/train')

test_dir = os.path.join(dst_path, 'cifar10/test')

print('total training  images:', len(os.listdir(train_dir)))

print('total test images:', len(os.listdir(test_dir)))
# Out:
# total training  images: 10
# total test images: 10

# %%
# path
train_path = "/content/cifa10/cifar10/train/"
test_path = "/content/cifa10/cifar10/test/"

# %%
# library
import keras
import numpy as np
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import os
import scipy



# load Neural Network Model Library => condition 3 of assignment
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
# Set generator with rescaler(1./255) -> condition 2 of assignment
train_datagen = ImageDataGenerator(rescale=1./255, validation_split=0.1)
test_datagen = ImageDataGenerator(rescale=1./255)

# make a loading data flow from path. It generates data at each batch sizes -> condition 1 of assignment
batch_size_num = 100
train_generator = train_datagen.flow_from_directory(train_path,
                                                    classes=sorted(os.listdir(train_path)),
                                                    batch_size = batch_size_num,
                                                    target_size = (256, 256),
                                                    subset="training",
                                                    class_mode='categorical')

valid_generator = train_datagen.flow_from_directory(train_path, 
                                                    classes=sorted(os.listdir(train_path)), 
                                                    batch_size = batch_size_num, 
                                                    target_size=(256, 256), 
                                                    subset="validation",
                                                    class_mode='categorical')


test_generator = test_datagen.flow_from_directory(test_path, 
                                                  classes=sorted(os.listdir(test_path)),
                                                  batch_size = 100,
                                                  target_size = (256, 256),
                                                  class_mode='categorical')

print()
# check shape of data shape
print("check shape of data shape")
for x_data, class_data in train_generator:
    print(f"input data shape from train_generator: {x_data.shape}")
    print(f"class data shape from train_generator: {class_data.shape}")
    break

for x_data, class_data in valid_generator:
    print(f"input data shape from valid_generator: {x_data.shape}")
    print(f"class data shape from valid_generator: {class_data.shape}")
    break
    
for x_data, class_data in test_generator:
    print(f"input data shape from test_generator: {x_data.shape}")
    print(f"class data shape from test_generator: {class_data.shape}")
    break
# Out:
# Found 45000 images belonging to 10 classes.
# Found 5000 images belonging to 10 classes.
# Found 10000 images belonging to 10 classes.
#
# check shape of data shape
# input data shape from train_generator: (100, 256, 256, 3)
# class data shape from train_generator: (100, 10)
# input data shape from valid_generator: (100, 256, 256, 3)
# class data shape from valid_generator: (100, 10)
# input data shape from test_generator: (100, 256, 256, 3)
# class data shape from test_generator: (100, 10)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np

# MAML 모델 구성
model = keras.Sequential([
    layers.Conv2D(96, (11, 11), strides=(4, 4), padding='valid', activation='relu', input_shape=(256, 256, 3)),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)),
    layers.Conv2D(256, (5, 5), strides=(1, 1), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)),
    layers.Conv2D(384, (3, 3), strides=(1, 1), padding='same', activation='relu'),
    layers.Conv2D(384, (3, 3), strides=(1, 1), padding='same', activation='relu'),
    layers.Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu'),
    layers.MaxPooling2D(pool_size=(3, 3), strides=(2, 2)),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    # layers.Dense(10, activation='softmax')
    layers.Dense(5, activation='softmax')  # 클래스 개수에 맞게 변경
])

# %%
# MAML 모델 컴파일
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
# MAML 알고리즘 설정
meta_learning_rate = 0.001
inner_learning_rate = 0.01
num_tasks = 450
num_inner_updates = 5

# %%
# 메타-학습 반복
for meta_iteration in range(num_tasks):
    # task_indices = np.random.choice(len(x_train), num_tasks, replace=False)

    # 작업 별로 초기 파라미터 설정
    model_clone = keras.models.clone_model(model)
    model_clone.set_weights(model.get_weights())
    model_clone.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
    
    # train_generator의 클래스 개수
    num_classes = len(train_generator.class_indices)

    for inner_iteration in range(num_inner_updates):
       # 랜덤하게 5개의 클래스 선택
      random_classes = np.random.choice(num_classes, size=5, replace=False)
    
      # 선택한 클래스에 해당하는 데이터로 작업 데이터 생성
      x_task_train = []
      y_task_train = []
      x_task_val = []
      y_task_val = []
    for cls in random_classes:
        # 해당 클래스에 속하는 이미지들을 가져옴
        images, labels = train_generator.next()
        images1, labels1 = valid_generator.next()
        # 클래스에 해당하는 이미지와 레이블을 작업 데이터에 추가
        x_task_train.append(images)
        y_task_train.append(labels)
        x_task_val.append(images1)
        y_task_val.append(labels1)

        # 작업 데이터를 numpy 배열로 변환
    x_task_train = np.concatenate(x_task_train, axis=0)
    y_task_train = np.concatenate(y_task_train, axis=0)
    x_task_val = np.concatenate(x_task_val, axis=0)
    y_task_val = np.concatenate(y_task_val, axis=0)

    selected_classes = np.random.choice(10, size=5, replace=False)

    # 선택된 클래스들에 해당하는 인덱스를 추출하여 새로운 x_task_train과 y_task_train 생성
    selected_indices = np.isin(y_task_train.argmax(axis=1), selected_classes)

    x_task_train_selected = x_task_train[selected_indices]
    y_task_train_selected = y_task_train[selected_indices][:, selected_classes]
    x_task_val_selected = x_task_val[selected_indices]
    y_task_val_selected = y_task_val[selected_indices][:, selected_classes]

    for inner_iteration in range(num_inner_updates):
        # x_task_train, y_task_train = train_generator.next()

        # 그래디언트 계산을 위해 작업 데이터로 모델 학습
        model_clone.train_on_batch(x_task_train_selected, y_task_train_selected)
        
        # 미세 조정을 위해 학습한 모델 파라미터를 업데이트
        model_weights = model_clone.get_weights()
        model.set_weights(model_weights)

    # 메타-학습을 위해 초기 파라미터를 업데이트
    model_weights = model.get_weights()
    for i, weight in enumerate(model_weights):
        model_weights[i] = weight + meta_learning_rate * (weight - model_clone.get_weights()[i])
    model.set_weights(model_weights)

    # 현재 meta_iteration에서의 val 데이터셋에 대한 손실과 정확도 출력
    # x_val, y_val = valid_generator.next()
    val_loss, val_acc = model.evaluate(x_task_val_selected, y_task_val_selected)
    # print(f"Meta Iteration: {meta_iteration + 1}  val Loss: {val_loss:.4f} val Acc: {val_acc:.4f}")
# Out:
# 8/8 [==============================] - 13s 1s/step - loss: 0.8775 - accuracy: 0.1235
# Meta Iteration: 1  val Loss: 0.8775 val Acc: 0.1235
# 8/8 [==============================] - 12s 2s/step - loss: 1.0420 - accuracy: 0.0854
# Meta Iteration: 2  val Loss: 1.0420 val Acc: 0.0854
# 8/8 [==============================] - 14s 2s/step - loss: 0.9350 - accuracy: 0.1053
# Meta Iteration: 3  val Loss: 0.9350 val Acc: 0.1053
# 9/9 [==============================] - 14s 2s/step - loss: 1.0115 - accuracy: 0.1034
# Meta Iteration: 4  val Loss: 1.0115 val Acc: 0.1034
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_train_function.<locals>.train_function at 0x7f1efe8ebc70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 9/9 [==============================] - 15s 2s/step - loss: 4.2599 - accuracy: 0.0856
# Meta Iteration: 5  val Loss: 4.2599 val Acc: 0.0856
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_train_function.<locals>.train_function at 0x7f1efde31c60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 8/8 [==============================] - 13s 2s/step - loss: 3.8176 - accuracy: 0.1205
# Meta Iteration: 6  val Loss: 3.8176 val Acc: 0.1205
# 8/8 [==============================] - 14s 2s/step - loss: 2.4110 - accuracy: 0.1155
# Meta Iteration: 7  val Loss: 2.4110 val Acc: 0.1155
# 8/8 [==============================] - 14s 2s/step - loss: 4.1367 - accuracy: 0.0751
# Meta Iteration: 8  val Loss: 4.1367 val Acc: 0.0751
# 8/8 [==============================] - 13s 2s/step - loss: 8.9028 - accuracy: 0.1021
# Meta Iteration: 9  val Loss: 8.9028 val Acc: 0.1021
# 8/8 [==============================] - 13s 2s/step - loss: 4.3966 - accuracy: 0.0706
# Meta Iteration: 10  val Loss: 4.3966 val Acc: 0.0706
# 9/9 [==============================] - 14s 2s/step - loss: 2.2645 - accuracy: 0.1154
# Meta Iteration: 11  val Loss: 2.2645 val Acc: 0.1154
# 7/7 [==============================] - 11s 2s/step - loss: 4.1076 - accuracy: 0.0731
# Meta Iteration: 12  val Loss: 4.1076 val Acc: 0.0731
# 8/8 [==============================] - 14s 2s/step - loss: 6.3145 - accuracy: 0.0824
# Meta Iteration: 13  val Loss: 6.3145 val Acc: 0.0824
# 9/9 [==============================] - 14s 2s/step - loss: 10.9019 - accuracy: 0.1264
# Meta Iteration: 14  val Loss: 10.9019 val Acc: 0.1264
# 8/8 [==============================] - 14s 2s/step - loss: 10.1070 - accuracy: 0.0964
# Meta Iteration: 15  val Loss: 10.1070 val Acc: 0.0964
# 8/8 [==============================] - 13s 2s/step - loss: 14.5255 - accuracy: 0.5878
# Meta Iteration: 16  val Loss: 14.5255 val Acc: 0.5878
# 8/8 [==============================] - 13s 2s/step - loss: 13.4751 - accuracy: 0.1020
# Meta Iteration: 17  val Loss: 13.4751 val Acc: 0.1020
# 9/9 [==============================] - 14s 2s/step - loss: 3.2683 - accuracy: 0.1012
# Meta Iteration: 18  val Loss: 3.2683 val Acc: 0.1012
# 8/8 [==============================] - 16s 2s/step - loss: 0.8131 - accuracy: 0.1133
# Meta Iteration: 19  val Loss: 0.8131 val Acc: 0.1133
# 8/8 [==============================] - 13s 2s/step - loss: 1.2319 - accuracy: 0.0962
# Meta Iteration: 20  val Loss: 1.2319 val Acc: 0.0962
# 9/9 [==============================] - 14s 2s/step - loss: 2.0244 - accuracy: 0.1008
# Meta Iteration: 21  val Loss: 2.0244 val Acc: 0.1008
# 8/8 [==============================] - 13s 2s/step - loss: 2.2760 - accuracy: 0.1134
# Meta Iteration: 22  val Loss: 2.2760 val Acc: 0.1134
# 8/8 [==============================] - 15s 2s/step - loss: 2.8113 - accuracy: 0.6061
# Meta Iteration: 23  val Loss: 2.8113 val Acc: 0.6061
# 8/8 [==============================] - 13s 2s/step - loss: 0.9696 - accuracy: 0.5280
# Meta Iteration: 24  val Loss: 0.9696 val Acc: 0.5280
# 9/9 [==============================] - 15s 2s/step - loss: 0.7943 - accuracy: 0.1481
# Meta Iteration: 25  val Loss: 0.7943 val Acc: 0.1481
# 8/8 [==============================] - 13s 2s/step - loss: 0.7696 - accuracy: 0.1102
# Meta Iteration: 26  val Loss: 0.7696 val Acc: 0.1102
# 8/8 [==============================] - 11s 1s/step - loss: 0.9750 - accuracy: 0.1186
# Meta Iteration: 27  val Loss: 0.9750 val Acc: 0.1186
# 9/9 [==============================] - 17s 2s/step - loss: 0.8800 - accuracy: 0.1065
# Meta Iteration: 28  val Loss: 0.8800 val Acc: 0.1065
# 8/8 [==============================] - 14s 2s/step - loss: 0.8126 - accuracy: 0.1951
# Meta Iteration: 29  val Loss: 0.8126 val Acc: 0.1951
# 9/9 [==============================] - 14s 2s/step - loss: 0.7540 - accuracy: 0.1089
# Meta Iteration: 30  val Loss: 0.7540 val Acc: 0.1089
# 8/8 [==============================] - 14s 2s/step - loss: 0.8323 - accuracy: 0.0947
# Meta Iteration: 31  val Loss: 0.8323 val Acc: 0.0947
# 8/8 [==============================] - 13s 2s/step - loss: 0.7871 - accuracy: 0.1029
# Meta Iteration: 32  val Loss: 0.7871 val Acc: 0.1029
# 8/8 [==============================] - 14s 2s/step - loss: 0.8072 - accuracy: 0.0797
# Meta Iteration: 33  val Loss: 0.8072 val Acc: 0.0797
# 9/9 [==============================] - 14s 2s/step - loss: 0.8693 - accuracy: 0.1660
# Meta Iteration: 34  val Loss: 0.8693 val Acc: 0.1660
# 9/9 [==============================] - 14s 2s/step - loss: 4.5675 - accuracy: 0.1279
# Meta Iteration: 35  val Loss: 4.5675 val Acc: 0.1279
# 9/9 [==============================] - 14s 2s/step - loss: 1.0470 - accuracy: 0.0695
# Meta Iteration: 36  val Loss: 1.0470 val Acc: 0.0695
# 9/9 [==============================] - 14s 2s/step - loss: 0.8896 - accuracy: 0.1170
# Meta Iteration: 37  val Loss: 0.8896 val Acc: 0.1170
# 9/9 [==============================] - 15s 2s/step - loss: 0.7784 - accuracy: 0.6073
# Meta Iteration: 38  val Loss: 0.7784 val Acc: 0.6073
# 8/8 [==============================] - 13s 2s/step - loss: 1.8975 - accuracy: 0.1314
# Meta Iteration: 39  val Loss: 1.8975 val Acc: 0.1314
# 8/8 [==============================] - 13s 2s/step - loss: 0.9435 - accuracy: 0.0782
# Meta Iteration: 40  val Loss: 0.9435 val Acc: 0.0782
# 9/9 [==============================] - 14s 2s/step - loss: 0.9807 - accuracy: 0.1358
# Meta Iteration: 41  val Loss: 0.9807 val Acc: 0.1358
# 9/9 [==============================] - 14s 2s/step - loss: 0.9035 - accuracy: 0.1115
# Meta Iteration: 42  val Loss: 0.9035 val Acc: 0.1115
# 9/9 [==============================] - 14s 2s/step - loss: 1.5650 - accuracy: 0.1163
# Meta Iteration: 43  val Loss: 1.5650 val Acc: 0.1163
# 8/8 [==============================] - 13s 1s/step - loss: 0.8377 - accuracy: 0.1107
# Meta Iteration: 44  val Loss: 0.8377 val Acc: 0.1107
# 8/8 [==============================] - 13s 2s/step - loss: 0.8247 - accuracy: 0.1674
# Meta Iteration: 45  val Loss: 0.8247 val Acc: 0.1674
# 8/8 [==============================] - 14s 2s/step - loss: 0.8166 - accuracy: 0.1255
# Meta Iteration: 46  val Loss: 0.8166 val Acc: 0.1255
# 9/9 [==============================] - 13s 1s/step - loss: 0.7478 - accuracy: 0.1167
# Meta Iteration: 47  val Loss: 0.7478 val Acc: 0.1167
# 9/9 [==============================] - 14s 2s/step - loss: 0.8130 - accuracy: 0.4160
# Meta Iteration: 48  val Loss: 0.8130 val Acc: 0.4160
# 8/8 [==============================] - 14s 2s/step - loss: 0.8154 - accuracy: 0.5163
# Meta Iteration: 49  val Loss: 0.8154 val Acc: 0.5163
# 8/8 [==============================] - 14s 2s/step - loss: 0.7553 - accuracy: 0.1639
# Meta Iteration: 50  val Loss: 0.7553 val Acc: 0.1639
# 8/8 [==============================] - 13s 2s/step - loss: 0.8454 - accuracy: 0.1265
# Meta Iteration: 51  val Loss: 0.8454 val Acc: 0.1265
# 9/9 [==============================] - 14s 2s/step - loss: 0.9364 - accuracy: 0.0846
# Meta Iteration: 52  val Loss: 0.9364 val Acc: 0.0846
# 8/8 [==============================] - 13s 2s/step - loss: 0.9464 - accuracy: 0.1218
# Meta Iteration: 53  val Loss: 0.9464 val Acc: 0.1218
# 8/8 [==============================] - 14s 2s/step - loss: 1.0516 - accuracy: 0.0916
# Meta Iteration: 54  val Loss: 1.0516 val Acc: 0.0916
# 9/9 [==============================] - 14s 2s/step - loss: 0.9137 - accuracy: 0.0881
# Meta Iteration: 55  val Loss: 0.9137 val Acc: 0.0881
# 9/9 [==============================] - 14s 2s/step - loss: 0.8797 - accuracy: 0.0840
# Meta Iteration: 56  val Loss: 0.8797 val Acc: 0.0840
# 8/8 [==============================] - 14s 2s/step - loss: 2.8474 - accuracy: 0.1235
# Meta Iteration: 57  val Loss: 2.8474 val Acc: 0.1235
# 9/9 [==============================] - 13s 1s/step - loss: 1.2128 - accuracy: 0.1158
# Meta Iteration: 58  val Loss: 1.2128 val Acc: 0.1158
# 8/8 [==============================] - 14s 2s/step - loss: 18.1591 - accuracy: 0.0902
# Meta Iteration: 59  val Loss: 18.1591 val Acc: 0.0902
# 9/9 [==============================] - 14s 2s/step - loss: 5.1514 - accuracy: 0.0642
# Meta Iteration: 60  val Loss: 5.1514 val Acc: 0.0642
# 8/8 [==============================] - 16s 2s/step - loss: 2.3854 - accuracy: 0.0891
# Meta Iteration: 61  val Loss: 2.3854 val Acc: 0.0891
# 8/8 [==============================] - 13s 2s/step - loss: 2.3107 - accuracy: 0.1125
# Meta Iteration: 62  val Loss: 2.3107 val Acc: 0.1125
# 8/8 [==============================] - 14s 2s/step - loss: 0.7029 - accuracy: 0.1107
# Meta Iteration: 63  val Loss: 0.7029 val Acc: 0.1107
# 8/8 [==============================] - 14s 2s/step - loss: 0.7446 - accuracy: 0.1355
# Meta Iteration: 64  val Loss: 0.7446 val Acc: 0.1355
# 8/8 [==============================] - 13s 2s/step - loss: 1.6700 - accuracy: 0.0925
# Meta Iteration: 65  val Loss: 1.6700 val Acc: 0.0925
# 8/8 [==============================] - 14s 2s/step - loss: 0.9418 - accuracy: 0.0810
# Meta Iteration: 66  val Loss: 0.9418 val Acc: 0.0810
# 8/8 [==============================] - 13s 2s/step - loss: 0.6930 - accuracy: 0.0932
# Meta Iteration: 67  val Loss: 0.6930 val Acc: 0.0932
# 8/8 [==============================] - 13s 2s/step - loss: 1.2026 - accuracy: 0.0681
# Meta Iteration: 68  val Loss: 1.2026 val Acc: 0.0681
# 8/8 [==============================] - 13s 2s/step - loss: 0.8028 - accuracy: 0.1008
# Meta Iteration: 69  val Loss: 0.8028 val Acc: 0.1008
# 8/8 [==============================] - 12s 2s/step - loss: 0.7628 - accuracy: 0.0726
# Meta Iteration: 70  val Loss: 0.7628 val Acc: 0.0726
# 9/9 [==============================] - 14s 2s/step - loss: 0.8644 - accuracy: 0.1051
# Meta Iteration: 71  val Loss: 0.8644 val Acc: 0.1051
# 8/8 [==============================] - 13s 1s/step - loss: 0.7879 - accuracy: 0.1174
# Meta Iteration: 72  val Loss: 0.7879 val Acc: 0.1174
# 8/8 [==============================] - 14s 2s/step - loss: 0.8107 - accuracy: 0.2713
# Meta Iteration: 73  val Loss: 0.8107 val Acc: 0.2713
# 8/8 [==============================] - 13s 2s/step - loss: 0.8214 - accuracy: 0.0962
# Meta Iteration: 74  val Loss: 0.8214 val Acc: 0.0962
# 8/8 [==============================] - 13s 2s/step - loss: 0.8019 - accuracy: 0.1013
# Meta Iteration: 75  val Loss: 0.8019 val Acc: 0.1013
# 8/8 [==============================] - 13s 2s/step - loss: 0.8312 - accuracy: 0.1350
# Meta Iteration: 76  val Loss: 0.8312 val Acc: 0.1350
# 8/8 [==============================] - 13s 2s/step - loss: 0.8267 - accuracy: 0.1111
# Meta Iteration: 77  val Loss: 0.8267 val Acc: 0.1111
# 8/8 [==============================] - 13s 1s/step - loss: 1.0421 - accuracy: 0.0992
# Meta Iteration: 78  val Loss: 1.0421 val Acc: 0.0992
# 8/8 [==============================] - 13s 1s/step - loss: 3.1286 - accuracy: 0.1125
# Meta Iteration: 79  val Loss: 3.1286 val Acc: 0.1125
# 9/9 [==============================] - 14s 2s/step - loss: 0.9909 - accuracy: 0.1034
# Meta Iteration: 80  val Loss: 0.9909 val Acc: 0.1034
# 9/9 [==============================] - 14s 1s/step - loss: 3.1439 - accuracy: 0.0736
# Meta Iteration: 81  val Loss: 3.1439 val Acc: 0.0736
# 9/9 [==============================] - 14s 2s/step - loss: 0.8578 - accuracy: 0.0868
# Meta Iteration: 82  val Loss: 0.8578 val Acc: 0.0868
# 8/8 [==============================] - 13s 2s/step - loss: 0.8614 - accuracy: 0.1631
# Meta Iteration: 83  val Loss: 0.8614 val Acc: 0.1631
# 8/8 [==============================] - 13s 2s/step - loss: 0.8006 - accuracy: 0.6352
# Meta Iteration: 84  val Loss: 0.8006 val Acc: 0.6352
# 8/8 [==============================] - 13s 2s/step - loss: 0.8366 - accuracy: 0.0871
# Meta Iteration: 85  val Loss: 0.8366 val Acc: 0.0871
# 8/8 [==============================] - 14s 2s/step - loss: 0.8401 - accuracy: 0.1434
# Meta Iteration: 86  val Loss: 0.8401 val Acc: 0.1434
# 9/9 [==============================] - 14s 2s/step - loss: 0.7018 - accuracy: 0.0969
# Meta Iteration: 87  val Loss: 0.7018 val Acc: 0.0969
# 8/8 [==============================] - 14s 2s/step - loss: 0.7257 - accuracy: 0.1216
# Meta Iteration: 88  val Loss: 0.7257 val Acc: 0.1216
# 8/8 [==============================] - 15s 2s/step - loss: 0.9323 - accuracy: 0.0920
# Meta Iteration: 89  val Loss: 0.9323 val Acc: 0.0920
# 8/8 [==============================] - 12s 1s/step - loss: 0.7832 - accuracy: 0.0830
# Meta Iteration: 90  val Loss: 0.7832 val Acc: 0.0830
# 9/9 [==============================] - 14s 2s/step - loss: 0.7568 - accuracy: 0.0920
# Meta Iteration: 91  val Loss: 0.7568 val Acc: 0.0920
# 8/8 [==============================] - 14s 2s/step - loss: 0.8378 - accuracy: 0.3765
# Meta Iteration: 92  val Loss: 0.8378 val Acc: 0.3765
# 8/8 [==============================] - 14s 2s/step - loss: 0.7759 - accuracy: 0.1299
# Meta Iteration: 93  val Loss: 0.7759 val Acc: 0.1299
# 8/8 [==============================] - 13s 2s/step - loss: 0.9107 - accuracy: 0.0705
# Meta Iteration: 94  val Loss: 0.9107 val Acc: 0.0705
# 8/8 [==============================] - 14s 2s/step - loss: 1.4566 - accuracy: 0.1097
# Meta Iteration: 95  val Loss: 1.4566 val Acc: 0.1097
# 8/8 [==============================] - 15s 2s/step - loss: 0.8394 - accuracy: 0.0905
# Meta Iteration: 96  val Loss: 0.8394 val Acc: 0.0905
# 8/8 [==============================] - 14s 2s/step - loss: 0.8076 - accuracy: 0.1215
# Meta Iteration: 97  val Loss: 0.8076 val Acc: 0.1215
# 8/8 [==============================] - 13s 2s/step - loss: 1.0376 - accuracy: 0.1235
# Meta Iteration: 98  val Loss: 1.0376 val Acc: 0.1235
# 8/8 [==============================] - 13s 2s/step - loss: 0.8772 - accuracy: 0.0759
# Meta Iteration: 99  val Loss: 0.8772 val Acc: 0.0759
# 9/9 [==============================] - 15s 2s/step - loss: 1.0148 - accuracy: 0.0882
# Meta Iteration: 100  val Loss: 1.0148 val Acc: 0.0882
# 8/8 [==============================] - 14s 2s/step - loss: 0.8530 - accuracy: 0.1057
# Meta Iteration: 101  val Loss: 0.8530 val Acc: 0.1057
# 9/9 [==============================] - 15s 2s/step - loss: 0.8292 - accuracy: 0.2601
# Meta Iteration: 102  val Loss: 0.8292 val Acc: 0.2601
# 9/9 [==============================] - 14s 2s/step - loss: 0.8139 - accuracy: 0.1395
# Meta Iteration: 103  val Loss: 0.8139 val Acc: 0.1395
# 8/8 [==============================] - 13s 2s/step - loss: 0.7495 - accuracy: 0.1411
# Meta Iteration: 104  val Loss: 0.7495 val Acc: 0.1411
# 8/8 [==============================] - 13s 2s/step - loss: 0.7954 - accuracy: 0.1605
# Meta Iteration: 105  val Loss: 0.7954 val Acc: 0.1605
# 8/8 [==============================] - 14s 2s/step - loss: 0.8617 - accuracy: 0.0887
# Meta Iteration: 106  val Loss: 0.8617 val Acc: 0.0887
# 8/8 [==============================] - 14s 2s/step - loss: 0.7985 - accuracy: 0.1548
# Meta Iteration: 107  val Loss: 0.7985 val Acc: 0.1548
# 8/8 [==============================] - 13s 2s/step - loss: 0.9016 - accuracy: 0.1364
# Meta Iteration: 108  val Loss: 0.9016 val Acc: 0.1364
# 9/9 [==============================] - 14s 2s/step - loss: 0.8315 - accuracy: 0.2374
# Meta Iteration: 109  val Loss: 0.8315 val Acc: 0.2374
# 8/8 [==============================] - 13s 1s/step - loss: 0.8270 - accuracy: 0.0979
# Meta Iteration: 110  val Loss: 0.8270 val Acc: 0.0979
# 8/8 [==============================] - 14s 2s/step - loss: 0.7495 - accuracy: 0.0785
# Meta Iteration: 111  val Loss: 0.7495 val Acc: 0.0785
# 8/8 [==============================] - 13s 2s/step - loss: 0.7886 - accuracy: 0.1341
# Meta Iteration: 112  val Loss: 0.7886 val Acc: 0.1341
# 8/8 [==============================] - 14s 2s/step - loss: 1.2991 - accuracy: 0.0956
# Meta Iteration: 113  val Loss: 1.2991 val Acc: 0.0956
# 8/8 [==============================] - 14s 2s/step - loss: 0.7873 - accuracy: 0.1055
# Meta Iteration: 114  val Loss: 0.7873 val Acc: 0.1055
# 8/8 [==============================] - 14s 2s/step - loss: 0.8112 - accuracy: 0.0949
# Meta Iteration: 115  val Loss: 0.8112 val Acc: 0.0949
# 9/9 [==============================] - 14s 2s/step - loss: 0.8968 - accuracy: 0.1073
# Meta Iteration: 116  val Loss: 0.8968 val Acc: 0.1073
# 8/8 [==============================] - 12s 1s/step - loss: 0.8195 - accuracy: 0.0950
# Meta Iteration: 117  val Loss: 0.8195 val Acc: 0.0950
# 7/7 [==============================] - 11s 1s/step - loss: 0.7797 - accuracy: 0.1031
# Meta Iteration: 118  val Loss: 0.7797 val Acc: 0.1031
# 8/8 [==============================] - 14s 2s/step - loss: 0.8562 - accuracy: 0.0941
# Meta Iteration: 119  val Loss: 0.8562 val Acc: 0.0941
# 8/8 [==============================] - 15s 2s/step - loss: 0.7731 - accuracy: 0.1270
# Meta Iteration: 120  val Loss: 0.7731 val Acc: 0.1270
# 8/8 [==============================] - 13s 2s/step - loss: 0.7798 - accuracy: 0.0688
# Meta Iteration: 121  val Loss: 0.7798 val Acc: 0.0688
# 9/9 [==============================] - 14s 2s/step - loss: 0.9872 - accuracy: 0.0940
# Meta Iteration: 122  val Loss: 0.9872 val Acc: 0.0940
# 8/8 [==============================] - 13s 2s/step - loss: 0.7816 - accuracy: 0.0891
# Meta Iteration: 123  val Loss: 0.7816 val Acc: 0.0891
# 8/8 [==============================] - 14s 2s/step - loss: 0.7763 - accuracy: 0.0760
# Meta Iteration: 124  val Loss: 0.7763 val Acc: 0.0760
# 8/8 [==============================] - 14s 2s/step - loss: 0.7196 - accuracy: 0.0476
# Meta Iteration: 125  val Loss: 0.7196 val Acc: 0.0476
# 9/9 [==============================] - 14s 2s/step - loss: 0.9020 - accuracy: 0.1015
# Meta Iteration: 126  val Loss: 0.9020 val Acc: 0.1015
# 9/9 [==============================] - 15s 2s/step - loss: 0.7956 - accuracy: 0.1027
# Meta Iteration: 127  val Loss: 0.7956 val Acc: 0.1027
# 8/8 [==============================] - 13s 2s/step - loss: 0.7593 - accuracy: 0.0667
# Meta Iteration: 128  val Loss: 0.7593 val Acc: 0.0667
# 9/9 [==============================] - 14s 1s/step - loss: 0.8051 - accuracy: 0.1197
# Meta Iteration: 129  val Loss: 0.8051 val Acc: 0.1197
# 8/8 [==============================] - 15s 2s/step - loss: 0.8553 - accuracy: 0.0730
# Meta Iteration: 130  val Loss: 0.8553 val Acc: 0.0730
# 9/9 [==============================] - 14s 2s/step - loss: 0.8921 - accuracy: 0.0846
# Meta Iteration: 131  val Loss: 0.8921 val Acc: 0.0846
# 8/8 [==============================] - 14s 2s/step - loss: 0.7897 - accuracy: 0.1210
# Meta Iteration: 132  val Loss: 0.7897 val Acc: 0.1210
# 9/9 [==============================] - 14s 2s/step - loss: 1.0140 - accuracy: 0.0913
# Meta Iteration: 133  val Loss: 1.0140 val Acc: 0.0913
# 8/8 [==============================] - 13s 2s/step - loss: 0.9226 - accuracy: 0.1097
# Meta Iteration: 134  val Loss: 0.9226 val Acc: 0.1097
# 9/9 [==============================] - 14s 2s/step - loss: 0.7852 - accuracy: 0.1298
# Meta Iteration: 135  val Loss: 0.7852 val Acc: 0.1298
# 8/8 [==============================] - 14s 2s/step - loss: 0.7690 - accuracy: 0.0632
# Meta Iteration: 136  val Loss: 0.7690 val Acc: 0.0632
# 8/8 [==============================] - 14s 2s/step - loss: 0.8931 - accuracy: 0.0927
# Meta Iteration: 137  val Loss: 0.8931 val Acc: 0.0927
# 9/9 [==============================] - 15s 2s/step - loss: 0.7905 - accuracy: 0.0837
# Meta Iteration: 138  val Loss: 0.7905 val Acc: 0.0837
# 8/8 [==============================] - 13s 2s/step - loss: 0.7742 - accuracy: 0.0851
# Meta Iteration: 139  val Loss: 0.7742 val Acc: 0.0851
# 9/9 [==============================] - 14s 2s/step - loss: 0.8409 - accuracy: 0.0875
# Meta Iteration: 140  val Loss: 0.8409 val Acc: 0.0875
# 8/8 [==============================] - 14s 2s/step - loss: 0.8084 - accuracy: 0.1446
# Meta Iteration: 141  val Loss: 0.8084 val Acc: 0.1446
# 9/9 [==============================] - 14s 2s/step - loss: 0.7315 - accuracy: 0.1065
# Meta Iteration: 142  val Loss: 0.7315 val Acc: 0.1065
# 8/8 [==============================] - 14s 2s/step - loss: 0.7897 - accuracy: 0.0902
# Meta Iteration: 143  val Loss: 0.7897 val Acc: 0.0902
# 8/8 [==============================] - 14s 2s/step - loss: 0.8146 - accuracy: 0.1028
# Meta Iteration: 144  val Loss: 0.8146 val Acc: 0.1028
# 8/8 [==============================] - 13s 2s/step - loss: 0.7786 - accuracy: 0.1000
# Meta Iteration: 145  val Loss: 0.7786 val Acc: 0.1000
# 8/8 [==============================] - 17s 2s/step - loss: 0.8452 - accuracy: 0.1016
# Meta Iteration: 146  val Loss: 0.8452 val Acc: 0.1016
# 8/8 [==============================] - 14s 2s/step - loss: 0.7965 - accuracy: 0.1224
# Meta Iteration: 147  val Loss: 0.7965 val Acc: 0.1224
# 8/8 [==============================] - 14s 2s/step - loss: 0.7695 - accuracy: 0.0977
# Meta Iteration: 148  val Loss: 0.7695 val Acc: 0.0977
# 8/8 [==============================] - 11s 1s/step - loss: 0.7445 - accuracy: 0.1082
# Meta Iteration: 149  val Loss: 0.7445 val Acc: 0.1082
# 8/8 [==============================] - 13s 1s/step - loss: 0.8841 - accuracy: 0.0984
# Meta Iteration: 150  val Loss: 0.8841 val Acc: 0.0984
# 8/8 [==============================] - 13s 2s/step - loss: 0.7112 - accuracy: 0.1138
# Meta Iteration: 151  val Loss: 0.7112 val Acc: 0.1138
# 9/9 [==============================] - 14s 2s/step - loss: 0.8565 - accuracy: 0.1047
# Meta Iteration: 152  val Loss: 0.8565 val Acc: 0.1047
# 9/9 [==============================] - 15s 2s/step - loss: 0.9545 - accuracy: 0.0993
# Meta Iteration: 153  val Loss: 0.9545 val Acc: 0.0993
# 9/9 [==============================] - 14s 2s/step - loss: 0.8245 - accuracy: 0.0784
# Meta Iteration: 154  val Loss: 0.8245 val Acc: 0.0784
# 8/8 [==============================] - 13s 2s/step - loss: 0.7661 - accuracy: 0.0745
# Meta Iteration: 155  val Loss: 0.7661 val Acc: 0.0745
# 8/8 [==============================] - 14s 2s/step - loss: 0.8882 - accuracy: 0.0806
# Meta Iteration: 156  val Loss: 0.8882 val Acc: 0.0806
# 8/8 [==============================] - 12s 1s/step - loss: 0.8986 - accuracy: 0.1926
# Meta Iteration: 157  val Loss: 0.8986 val Acc: 0.1926
# 9/9 [==============================] - 14s 2s/step - loss: 0.6943 - accuracy: 0.0973
# Meta Iteration: 158  val Loss: 0.6943 val Acc: 0.0973
# 9/9 [==============================] - 14s 2s/step - loss: 0.8018 - accuracy: 0.0895
# Meta Iteration: 159  val Loss: 0.8018 val Acc: 0.0895
# 9/9 [==============================] - 13s 1s/step - loss: 0.8334 - accuracy: 0.1012
# Meta Iteration: 160  val Loss: 0.8334 val Acc: 0.1012
# 9/9 [==============================] - 15s 2s/step - loss: 0.9910 - accuracy: 0.0812
# Meta Iteration: 161  val Loss: 0.9910 val Acc: 0.0812
# 9/9 [==============================] - 15s 2s/step - loss: 0.7662 - accuracy: 0.1055
# Meta Iteration: 162  val Loss: 0.7662 val Acc: 0.1055
# 8/8 [==============================] - 13s 2s/step - loss: 0.8369 - accuracy: 0.1193
# Meta Iteration: 163  val Loss: 0.8369 val Acc: 0.1193
# 8/8 [==============================] - 16s 2s/step - loss: 0.7308 - accuracy: 0.0843
# Meta Iteration: 164  val Loss: 0.7308 val Acc: 0.0843
# 8/8 [==============================] - 11s 1s/step - loss: 0.8449 - accuracy: 0.0996
# Meta Iteration: 165  val Loss: 0.8449 val Acc: 0.0996
# 8/8 [==============================] - 13s 2s/step - loss: 0.8469 - accuracy: 0.1130
# Meta Iteration: 166  val Loss: 0.8469 val Acc: 0.1130
# 8/8 [==============================] - 16s 2s/step - loss: 0.7144 - accuracy: 0.0906
# Meta Iteration: 167  val Loss: 0.7144 val Acc: 0.0906
# 8/8 [==============================] - 14s 2s/step - loss: 0.7910 - accuracy: 0.1133
# Meta Iteration: 168  val Loss: 0.7910 val Acc: 0.1133
# 8/8 [==============================] - 12s 2s/step - loss: 0.7692 - accuracy: 0.0664
# Meta Iteration: 169  val Loss: 0.7692 val Acc: 0.0664
# 8/8 [==============================] - 16s 2s/step - loss: 0.7791 - accuracy: 0.0887
# Meta Iteration: 170  val Loss: 0.7791 val Acc: 0.0887
# 9/9 [==============================] - 14s 2s/step - loss: 0.8486 - accuracy: 0.1170
# Meta Iteration: 171  val Loss: 0.8486 val Acc: 0.1170
# 9/9 [==============================] - 14s 2s/step - loss: 0.7809 - accuracy: 0.1183
# Meta Iteration: 172  val Loss: 0.7809 val Acc: 0.1183
# 9/9 [==============================] - 13s 1s/step - loss: 0.8607 - accuracy: 0.1053
# Meta Iteration: 173  val Loss: 0.8607 val Acc: 0.1053
# 9/9 [==============================] - 14s 2s/step - loss: 0.7994 - accuracy: 0.0954
# Meta Iteration: 174  val Loss: 0.7994 val Acc: 0.0954
# 8/8 [==============================] - 14s 2s/step - loss: 0.7768 - accuracy: 0.1016
# Meta Iteration: 175  val Loss: 0.7768 val Acc: 0.1016
# 8/8 [==============================] - 14s 2s/step - loss: 0.8432 - accuracy: 0.1028
# Meta Iteration: 176  val Loss: 0.8432 val Acc: 0.1028
# 8/8 [==============================] - 14s 2s/step - loss: 0.8001 - accuracy: 0.1024
# Meta Iteration: 177  val Loss: 0.8001 val Acc: 0.1024
# 9/9 [==============================] - 14s 2s/step - loss: 0.8863 - accuracy: 0.1331
# Meta Iteration: 178  val Loss: 0.8863 val Acc: 0.1331
# 8/8 [==============================] - 11s 1s/step - loss: 0.8206 - accuracy: 0.1050
# Meta Iteration: 179  val Loss: 0.8206 val Acc: 0.1050
# 8/8 [==============================] - 14s 2s/step - loss: 1.8504 - accuracy: 0.0873
# Meta Iteration: 180  val Loss: 1.8504 val Acc: 0.0873
# 8/8 [==============================] - 13s 2s/step - loss: 0.8394 - accuracy: 0.0652
# Meta Iteration: 181  val Loss: 0.8394 val Acc: 0.0652
# 8/8 [==============================] - 14s 2s/step - loss: 0.9066 - accuracy: 0.0945
# Meta Iteration: 182  val Loss: 0.9066 val Acc: 0.0945
# 8/8 [==============================] - 13s 2s/step - loss: 0.8001 - accuracy: 0.0813
# Meta Iteration: 183  val Loss: 0.8001 val Acc: 0.0813
# 8/8 [==============================] - 14s 2s/step - loss: 0.7997 - accuracy: 0.0757
# Meta Iteration: 184  val Loss: 0.7997 val Acc: 0.0757
# 8/8 [==============================] - 13s 1s/step - loss: 2.1066 - accuracy: 0.0795
# Meta Iteration: 185  val Loss: 2.1066 val Acc: 0.0795
# 8/8 [==============================] - 14s 2s/step - loss: 1.3088 - accuracy: 0.1496
# Meta Iteration: 186  val Loss: 1.3088 val Acc: 0.1496
# 8/8 [==============================] - 13s 2s/step - loss: 0.9197 - accuracy: 0.0992
# Meta Iteration: 187  val Loss: 0.9197 val Acc: 0.0992
# 8/8 [==============================] - 13s 2s/step - loss: 1.2626 - accuracy: 0.1382
# Meta Iteration: 188  val Loss: 1.2626 val Acc: 0.1382
# 8/8 [==============================] - 14s 2s/step - loss: 0.9277 - accuracy: 0.2088
# Meta Iteration: 189  val Loss: 0.9277 val Acc: 0.2088
# 8/8 [==============================] - 13s 1s/step - loss: 1.0087 - accuracy: 0.1800
# Meta Iteration: 190  val Loss: 1.0087 val Acc: 0.1800
# 9/9 [==============================] - 14s 2s/step - loss: 1.7622 - accuracy: 0.2231
# Meta Iteration: 191  val Loss: 1.7622 val Acc: 0.2231
# 8/8 [==============================] - 13s 2s/step - loss: 2.2450 - accuracy: 0.1064
# Meta Iteration: 192  val Loss: 2.2450 val Acc: 0.1064
# 9/9 [==============================] - 13s 1s/step - loss: 0.8280 - accuracy: 0.1533
# Meta Iteration: 193  val Loss: 0.8280 val Acc: 0.1533
# 9/9 [==============================] - 14s 2s/step - loss: 0.9095 - accuracy: 0.1226
# Meta Iteration: 194  val Loss: 0.9095 val Acc: 0.1226
# 8/8 [==============================] - 13s 2s/step - loss: 3.8407 - accuracy: 0.0913
# Meta Iteration: 195  val Loss: 3.8407 val Acc: 0.0913
# 8/8 [==============================] - 16s 2s/step - loss: 1.0795 - accuracy: 0.0976
# Meta Iteration: 196  val Loss: 1.0795 val Acc: 0.0976
# 9/9 [==============================] - 14s 2s/step - loss: 0.7748 - accuracy: 0.0970
# Meta Iteration: 197  val Loss: 0.7748 val Acc: 0.0970
# 8/8 [==============================] - 13s 2s/step - loss: 0.9001 - accuracy: 0.1368
# Meta Iteration: 198  val Loss: 0.9001 val Acc: 0.1368
# 9/9 [==============================] - 15s 2s/step - loss: 0.8486 - accuracy: 0.1174
# Meta Iteration: 199  val Loss: 0.8486 val Acc: 0.1174
# 9/9 [==============================] - 14s 1s/step - loss: 0.6889 - accuracy: 0.2192
# Meta Iteration: 200  val Loss: 0.6889 val Acc: 0.2192
# 9/9 [==============================] - 15s 2s/step - loss: 0.8993 - accuracy: 0.1031
# Meta Iteration: 201  val Loss: 0.8993 val Acc: 0.1031
# 9/9 [==============================] - 14s 1s/step - loss: 0.9036 - accuracy: 0.0758
# Meta Iteration: 202  val Loss: 0.9036 val Acc: 0.0758
# 8/8 [==============================] - 13s 2s/step - loss: 0.8424 - accuracy: 0.1429
# Meta Iteration: 203  val Loss: 0.8424 val Acc: 0.1429
# 8/8 [==============================] - 16s 2s/step - loss: 0.7785 - accuracy: 0.1230
# Meta Iteration: 204  val Loss: 0.7785 val Acc: 0.1230
# 8/8 [==============================] - 13s 2s/step - loss: 0.8343 - accuracy: 0.2008
# Meta Iteration: 205  val Loss: 0.8343 val Acc: 0.2008
# 9/9 [==============================] - 14s 1s/step - loss: 0.7966 - accuracy: 0.0927
# Meta Iteration: 206  val Loss: 0.7966 val Acc: 0.0927
# 8/8 [==============================] - 14s 2s/step - loss: 0.8527 - accuracy: 0.1116
# Meta Iteration: 207  val Loss: 0.8527 val Acc: 0.1116
# 8/8 [==============================] - 14s 2s/step - loss: 0.9072 - accuracy: 0.0669
# Meta Iteration: 208  val Loss: 0.9072 val Acc: 0.0669
# 8/8 [==============================] - 12s 1s/step - loss: 0.8195 - accuracy: 0.1088
# Meta Iteration: 209  val Loss: 0.8195 val Acc: 0.1088
# 8/8 [==============================] - 14s 2s/step - loss: 0.8020 - accuracy: 0.1129
# Meta Iteration: 210  val Loss: 0.8020 val Acc: 0.1129
# 9/9 [==============================] - 15s 2s/step - loss: 0.8412 - accuracy: 0.4577
# Meta Iteration: 211  val Loss: 0.8412 val Acc: 0.4577
# 9/9 [==============================] - 18s 2s/step - loss: 0.8157 - accuracy: 0.3173
# Meta Iteration: 212  val Loss: 0.8157 val Acc: 0.3173
# 8/8 [==============================] - 12s 2s/step - loss: 0.9064 - accuracy: 0.1632
# Meta Iteration: 213  val Loss: 0.9064 val Acc: 0.1632
# 9/9 [==============================] - 14s 2s/step - loss: 0.8237 - accuracy: 0.0728
# Meta Iteration: 214  val Loss: 0.8237 val Acc: 0.0728
# 9/9 [==============================] - 15s 2s/step - loss: 0.7792 - accuracy: 0.1679
# Meta Iteration: 215  val Loss: 0.7792 val Acc: 0.1679
# 8/8 [==============================] - 14s 2s/step - loss: 0.8664 - accuracy: 0.1944
# Meta Iteration: 216  val Loss: 0.8664 val Acc: 0.1944
# 8/8 [==============================] - 16s 2s/step - loss: 0.7949 - accuracy: 0.1290
# Meta Iteration: 217  val Loss: 0.7949 val Acc: 0.1290
# 9/9 [==============================] - 15s 2s/step - loss: 0.7770 - accuracy: 0.0929
# Meta Iteration: 218  val Loss: 0.7770 val Acc: 0.0929
# 9/9 [==============================] - 15s 2s/step - loss: 0.8176 - accuracy: 0.3068
# Meta Iteration: 219  val Loss: 0.8176 val Acc: 0.3068
# 8/8 [==============================] - 14s 2s/step - loss: 0.7870 - accuracy: 0.1873
# Meta Iteration: 220  val Loss: 0.7870 val Acc: 0.1873
# 8/8 [==============================] - 14s 2s/step - loss: 0.8643 - accuracy: 0.1523
# Meta Iteration: 221  val Loss: 0.8643 val Acc: 0.1523
# 8/8 [==============================] - 16s 2s/step - loss: 0.8152 - accuracy: 0.1646
# Meta Iteration: 222  val Loss: 0.8152 val Acc: 0.1646
# 8/8 [==============================] - 13s 2s/step - loss: 0.7930 - accuracy: 0.1983
# Meta Iteration: 223  val Loss: 0.7930 val Acc: 0.1983
# 8/8 [==============================] - 14s 2s/step - loss: 0.9331 - accuracy: 0.4048
# Meta Iteration: 224  val Loss: 0.9331 val Acc: 0.4048
# 8/8 [==============================] - 14s 2s/step - loss: 0.9077 - accuracy: 0.1383
# Meta Iteration: 225  val Loss: 0.9077 val Acc: 0.1383
# 9/9 [==============================] - 14s 2s/step - loss: 0.8671 - accuracy: 0.1124
# Meta Iteration: 226  val Loss: 0.8671 val Acc: 0.1124
# 8/8 [==============================] - 14s 2s/step - loss: 1.0393 - accuracy: 0.1250
# Meta Iteration: 227  val Loss: 1.0393 val Acc: 0.1250
# 9/9 [==============================] - 14s 2s/step - loss: 0.7631 - accuracy: 0.1473
# Meta Iteration: 228  val Loss: 0.7631 val Acc: 0.1473
# 9/9 [==============================] - 14s 2s/step - loss: 0.9633 - accuracy: 0.1085
# Meta Iteration: 229  val Loss: 0.9633 val Acc: 0.1085
# 8/8 [==============================] - 14s 2s/step - loss: 0.8723 - accuracy: 0.0996
# Meta Iteration: 230  val Loss: 0.8723 val Acc: 0.0996
# 9/9 [==============================] - 15s 2s/step - loss: 0.8189 - accuracy: 0.1350
# Meta Iteration: 231  val Loss: 0.8189 val Acc: 0.1350
# 8/8 [==============================] - 15s 2s/step - loss: 0.8108 - accuracy: 0.1310
# Meta Iteration: 232  val Loss: 0.8108 val Acc: 0.1310
# 8/8 [==============================] - 14s 2s/step - loss: 0.8128 - accuracy: 0.1811
# Meta Iteration: 233  val Loss: 0.8128 val Acc: 0.1811
# 8/8 [==============================] - 14s 2s/step - loss: 0.8438 - accuracy: 0.1440
# Meta Iteration: 234  val Loss: 0.8438 val Acc: 0.1440
# 8/8 [==============================] - 14s 2s/step - loss: 0.8079 - accuracy: 0.1289
# Meta Iteration: 235  val Loss: 0.8079 val Acc: 0.1289
# 8/8 [==============================] - 13s 2s/step - loss: 0.8032 - accuracy: 0.1405
# Meta Iteration: 236  val Loss: 0.8032 val Acc: 0.1405
# 9/9 [==============================] - 14s 2s/step - loss: 0.8786 - accuracy: 0.2328
# Meta Iteration: 237  val Loss: 0.8786 val Acc: 0.2328
# 8/8 [==============================] - 14s 2s/step - loss: 0.8886 - accuracy: 0.1016
# Meta Iteration: 238  val Loss: 0.8886 val Acc: 0.1016
# 8/8 [==============================] - 14s 2s/step - loss: 0.8725 - accuracy: 0.0863
# Meta Iteration: 239  val Loss: 0.8725 val Acc: 0.0863
# 8/8 [==============================] - 13s 2s/step - loss: 0.8605 - accuracy: 0.0655
# Meta Iteration: 240  val Loss: 0.8605 val Acc: 0.0655
# 9/9 [==============================] - 14s 2s/step - loss: 0.8920 - accuracy: 0.0734
# Meta Iteration: 241  val Loss: 0.8920 val Acc: 0.0734
# 8/8 [==============================] - 15s 2s/step - loss: 1.1666 - accuracy: 0.0843
# Meta Iteration: 242  val Loss: 1.1666 val Acc: 0.0843
# 9/9 [==============================] - 14s 1s/step - loss: 1.2813 - accuracy: 0.0824
# Meta Iteration: 243  val Loss: 1.2813 val Acc: 0.0824
# 8/8 [==============================] - 14s 2s/step - loss: 0.9209 - accuracy: 0.0920
# Meta Iteration: 244  val Loss: 0.9209 val Acc: 0.0920
# 9/9 [==============================] - 15s 2s/step - loss: 0.7954 - accuracy: 0.1351
# Meta Iteration: 245  val Loss: 0.7954 val Acc: 0.1351
# 9/9 [==============================] - 14s 2s/step - loss: 0.9237 - accuracy: 0.0865
# Meta Iteration: 246  val Loss: 0.9237 val Acc: 0.0865
# 9/9 [==============================] - 17s 2s/step - loss: 1.0658 - accuracy: 0.0679
# Meta Iteration: 247  val Loss: 1.0658 val Acc: 0.0679
# 8/8 [==============================] - 14s 2s/step - loss: 9.9223 - accuracy: 0.1098
# Meta Iteration: 248  val Loss: 9.9223 val Acc: 0.1098
# 8/8 [==============================] - 14s 2s/step - loss: 1.0534 - accuracy: 0.0945
# Meta Iteration: 249  val Loss: 1.0534 val Acc: 0.0945
# 9/9 [==============================] - 15s 2s/step - loss: 0.8906 - accuracy: 0.0916
# Meta Iteration: 250  val Loss: 0.8906 val Acc: 0.0916
# 8/8 [==============================] - 14s 2s/step - loss: 0.8613 - accuracy: 0.1120
# Meta Iteration: 251  val Loss: 0.8613 val Acc: 0.1120
# 9/9 [==============================] - 13s 1s/step - loss: 0.8458 - accuracy: 0.1089
# Meta Iteration: 252  val Loss: 0.8458 val Acc: 0.1089
# 8/8 [==============================] - 14s 2s/step - loss: 0.8378 - accuracy: 0.0941
# Meta Iteration: 253  val Loss: 0.8378 val Acc: 0.0941
# 8/8 [==============================] - 15s 2s/step - loss: 0.8207 - accuracy: 0.1032
# Meta Iteration: 254  val Loss: 0.8207 val Acc: 0.1032
# 9/9 [==============================] - 15s 2s/step - loss: 0.9164 - accuracy: 0.1255
# Meta Iteration: 255  val Loss: 0.9164 val Acc: 0.1255
# 8/8 [==============================] - 14s 2s/step - loss: 0.8468 - accuracy: 0.1025
# Meta Iteration: 256  val Loss: 0.8468 val Acc: 0.1025
# 9/9 [==============================] - 14s 1s/step - loss: 0.7691 - accuracy: 0.1019
# Meta Iteration: 257  val Loss: 0.7691 val Acc: 0.1019
# 8/8 [==============================] - 14s 2s/step - loss: 0.8062 - accuracy: 0.0757
# Meta Iteration: 258  val Loss: 0.8062 val Acc: 0.0757
# 8/8 [==============================] - 14s 2s/step - loss: 0.7633 - accuracy: 0.1000
# Meta Iteration: 259  val Loss: 0.7633 val Acc: 0.1000
# 8/8 [==============================] - 14s 2s/step - loss: 1.0268 - accuracy: 0.0843
# Meta Iteration: 260  val Loss: 1.0268 val Acc: 0.0843
# 9/9 [==============================] - 17s 2s/step - loss: 0.9449 - accuracy: 0.0778
# Meta Iteration: 261  val Loss: 0.9449 val Acc: 0.0778
# 8/8 [==============================] - 14s 2s/step - loss: 1.2045 - accuracy: 0.1317
# Meta Iteration: 262  val Loss: 1.2045 val Acc: 0.1317
# 8/8 [==============================] - 13s 2s/step - loss: 1.1912 - accuracy: 0.0873
# Meta Iteration: 263  val Loss: 1.1912 val Acc: 0.0873
# 8/8 [==============================] - 13s 2s/step - loss: 1.1527 - accuracy: 0.1125
# Meta Iteration: 264  val Loss: 1.1527 val Acc: 0.1125
# 8/8 [==============================] - 13s 1s/step - loss: 1.1023 - accuracy: 0.0847
# Meta Iteration: 265  val Loss: 1.1023 val Acc: 0.0847
# 8/8 [==============================] - 14s 2s/step - loss: 0.7988 - accuracy: 0.0607
# Meta Iteration: 266  val Loss: 0.7988 val Acc: 0.0607
# 8/8 [==============================] - 13s 2s/step - loss: 0.8434 - accuracy: 0.0795
# Meta Iteration: 267  val Loss: 0.8434 val Acc: 0.0795
# 8/8 [==============================] - 14s 2s/step - loss: 0.8520 - accuracy: 0.1107
# Meta Iteration: 268  val Loss: 0.8520 val Acc: 0.1107
# 8/8 [==============================] - 14s 2s/step - loss: 0.7632 - accuracy: 0.1116
# Meta Iteration: 269  val Loss: 0.7632 val Acc: 0.1116
# 8/8 [==============================] - 14s 2s/step - loss: 0.6929 - accuracy: 0.1079
# Meta Iteration: 270  val Loss: 0.6929 val Acc: 0.1079
# 8/8 [==============================] - 13s 2s/step - loss: 0.8130 - accuracy: 0.1025
# Meta Iteration: 271  val Loss: 0.8130 val Acc: 0.1025
# 8/8 [==============================] - 14s 2s/step - loss: 0.8716 - accuracy: 0.2734
# Meta Iteration: 272  val Loss: 0.8716 val Acc: 0.2734
# 9/9 [==============================] - 15s 2s/step - loss: 0.7351 - accuracy: 0.0865
# Meta Iteration: 273  val Loss: 0.7351 val Acc: 0.0865
# 8/8 [==============================] - 14s 2s/step - loss: 0.7813 - accuracy: 0.0913
# Meta Iteration: 274  val Loss: 0.7813 val Acc: 0.0913
# 8/8 [==============================] - 14s 2s/step - loss: 0.7794 - accuracy: 0.1074
# Meta Iteration: 275  val Loss: 0.7794 val Acc: 0.1074
# 9/9 [==============================] - 14s 2s/step - loss: 0.7740 - accuracy: 0.0853
# Meta Iteration: 276  val Loss: 0.7740 val Acc: 0.0853
# 9/9 [==============================] - 14s 2s/step - loss: 0.7490 - accuracy: 0.1008
# Meta Iteration: 277  val Loss: 0.7490 val Acc: 0.1008
# 8/8 [==============================] - 12s 1s/step - loss: 0.8583 - accuracy: 0.1034
# Meta Iteration: 278  val Loss: 0.8583 val Acc: 0.1034
# 8/8 [==============================] - 14s 2s/step - loss: 0.8528 - accuracy: 0.1486
# Meta Iteration: 279  val Loss: 0.8528 val Acc: 0.1486
# 8/8 [==============================] - 14s 2s/step - loss: 0.8036 - accuracy: 0.0843
# Meta Iteration: 280  val Loss: 0.8036 val Acc: 0.0843
# 8/8 [==============================] - 14s 2s/step - loss: 0.7959 - accuracy: 0.1071
# Meta Iteration: 281  val Loss: 0.7959 val Acc: 0.1071
# 8/8 [==============================] - 13s 1s/step - loss: 0.8699 - accuracy: 0.0980
# Meta Iteration: 282  val Loss: 0.8699 val Acc: 0.0980
# 8/8 [==============================] - 14s 2s/step - loss: 0.8158 - accuracy: 0.0864
# Meta Iteration: 283  val Loss: 0.8158 val Acc: 0.0864
# 9/9 [==============================] - 17s 2s/step - loss: 0.7788 - accuracy: 0.0659
# Meta Iteration: 284  val Loss: 0.7788 val Acc: 0.0659
# 8/8 [==============================] - 13s 2s/step - loss: 0.8646 - accuracy: 0.1373
# Meta Iteration: 285  val Loss: 0.8646 val Acc: 0.1373
# 8/8 [==============================] - 14s 2s/step - loss: 0.7721 - accuracy: 0.0863
# Meta Iteration: 286  val Loss: 0.7721 val Acc: 0.0863
# 8/8 [==============================] - 14s 2s/step - loss: 0.7504 - accuracy: 0.0735
# Meta Iteration: 287  val Loss: 0.7504 val Acc: 0.0735
# 8/8 [==============================] - 14s 2s/step - loss: 0.7721 - accuracy: 0.1211
# Meta Iteration: 288  val Loss: 0.7721 val Acc: 0.1211
# 8/8 [==============================] - 14s 2s/step - loss: 0.8463 - accuracy: 0.1225
# Meta Iteration: 289  val Loss: 0.8463 val Acc: 0.1225
# 8/8 [==============================] - 14s 2s/step - loss: 0.8875 - accuracy: 0.0565
# Meta Iteration: 290  val Loss: 0.8875 val Acc: 0.0565
# 8/8 [==============================] - 14s 2s/step - loss: 0.7732 - accuracy: 0.1265
# Meta Iteration: 291  val Loss: 0.7732 val Acc: 0.1265
# 8/8 [==============================] - 14s 2s/step - loss: 0.7755 - accuracy: 0.1139
# Meta Iteration: 292  val Loss: 0.7755 val Acc: 0.1139
# 8/8 [==============================] - 14s 2s/step - loss: 0.7876 - accuracy: 0.1285
# Meta Iteration: 293  val Loss: 0.7876 val Acc: 0.1285
# 9/9 [==============================] - 14s 2s/step - loss: 0.8458 - accuracy: 0.1634
# Meta Iteration: 294  val Loss: 0.8458 val Acc: 0.1634
# 8/8 [==============================] - 15s 2s/step - loss: 0.8469 - accuracy: 0.1614
# Meta Iteration: 295  val Loss: 0.8469 val Acc: 0.1614
# 8/8 [==============================] - 14s 2s/step - loss: 0.8449 - accuracy: 0.0820
# Meta Iteration: 296  val Loss: 0.8449 val Acc: 0.0820
# 9/9 [==============================] - 17s 2s/step - loss: 0.8966 - accuracy: 0.0909
# Meta Iteration: 297  val Loss: 0.8966 val Acc: 0.0909
# 8/8 [==============================] - 14s 2s/step - loss: 0.7870 - accuracy: 0.1488
# Meta Iteration: 298  val Loss: 0.7870 val Acc: 0.1488
# 9/9 [==============================] - 14s 2s/step - loss: 0.8268 - accuracy: 0.1197
# Meta Iteration: 299  val Loss: 0.8268 val Acc: 0.1197
# 8/8 [==============================] - 14s 2s/step - loss: 0.7383 - accuracy: 0.1189
# Meta Iteration: 300  val Loss: 0.7383 val Acc: 0.1189
# 8/8 [==============================] - 13s 2s/step - loss: 0.7735 - accuracy: 0.0826
# Meta Iteration: 301  val Loss: 0.7735 val Acc: 0.0826
# 8/8 [==============================] - 14s 2s/step - loss: 0.7657 - accuracy: 0.1181
# Meta Iteration: 302  val Loss: 0.7657 val Acc: 0.1181
# 9/9 [==============================] - 14s 2s/step - loss: 0.8655 - accuracy: 0.1313
# Meta Iteration: 303  val Loss: 0.8655 val Acc: 0.1313
# 8/8 [==============================] - 14s 2s/step - loss: 0.8966 - accuracy: 0.1325
# Meta Iteration: 304  val Loss: 0.8966 val Acc: 0.1325
# 8/8 [==============================] - 14s 2s/step - loss: 0.7760 - accuracy: 0.0827
# Meta Iteration: 305  val Loss: 0.7760 val Acc: 0.0827
# 8/8 [==============================] - 14s 2s/step - loss: 0.8611 - accuracy: 0.1382
# Meta Iteration: 306  val Loss: 0.8611 val Acc: 0.1382
# 8/8 [==============================] - 14s 2s/step - loss: 0.7314 - accuracy: 0.1040
# Meta Iteration: 307  val Loss: 0.7314 val Acc: 0.1040
# 8/8 [==============================] - 14s 2s/step - loss: 0.7748 - accuracy: 0.0833
# Meta Iteration: 308  val Loss: 0.7748 val Acc: 0.0833
# 8/8 [==============================] - 14s 2s/step - loss: 1.0634 - accuracy: 0.1573
# Meta Iteration: 309  val Loss: 1.0634 val Acc: 0.1573

# %%
x_test, y_test = test_generator.next()

# %%
# MAML 모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print("Test Accuracy:", test_acc)

# %%
model.predict(x_test)

# %%
model.save("aaaa.h5")

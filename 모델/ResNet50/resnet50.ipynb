# %%
# !pip install --upgrade tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.3.3)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.8)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.5.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.54.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.1.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)

# %%
# 필요한 라이브러리 불러오기
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, BatchNormalization, Activation, Add, AveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.preprocessing.image import ImageDataGenerator

import numpy as np

# CIFAR-10 데이터셋 불러오기
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# 이미지 데이터 전처리 (정규화)
#255로 나누는 이유는 정규화
#픽셀값은 0~255값을 가지므로 255로 나누어 0~1의 값을 가지게함  // 정규화과정

x_train = x_train / 255.
x_test = x_test / 255.

x_train = tf.image.resize(x_train, (32, 32))
x_test = tf.image.resize(x_test, (32, 32))

# %%
# 레이블 데이터를 One-hot Encoding으로 변환
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
# conv_block

def conv(inputs, filters, kernel_size, strides, name):
    # Convolution layer
    x = tf.keras.layers.Conv2D(filters, kernel_size, strides=strides, padding='same', name=name+'_conv')(inputs)
    # Batch normalization
    x = tf.keras.layers.BatchNormalization(name=name+'_bn')(x)
    # ReLU activation
    x = tf.keras.layers.ReLU(name=name+'_relu')(x)
    
    return x

# %%
# identity_block
# use skip connection // shortcut
# 입력과 출력의 feature map의 크기와 채널 수가 동일

def identity(inputs, filters, kernel_size, name):
    # Shortcut connection
    shortcut = inputs
    # First conv block
    x = conv(inputs, filters, kernel_size, strides=1, name=name+'_conv1')
    # Second conv block
    x = conv(x, filters, kernel_size, strides=1, name=name+'_conv2')
    # Add shortcut and residual
    x = tf.keras.layers.add([shortcut, x], name=name+'_add')
    # ReLU activation
    x = tf.keras.layers.ReLU(name=name+'_relu')(x)
    
    return x

# %%
# projection_block
# use skip connection // shortcut
# 입력과 출력의 feature map의 크기와 채널 수가 다를 경우 사용

def projection(inputs, filters, kernel_size, strides, name):
    # Shortcut connection

    # 1*1컨볼루션 사용 중 // 입력값을 1x1 컨볼루션을 이용하여 출력값과 같은 채널 수로 변환한 후
    shortcut = tf.keras.layers.Conv2D(filters, 1, strides=strides, padding='same', name=name+'_conv')(inputs)
    # First conv block
    x = conv(inputs, filters, kernel_size, strides=strides, name=name+'_conv1')
    # Second conv block
    x = conv(x, filters, kernel_size, strides=1, name=name+'_conv2')
    # Add shortcut and residual
    x = tf.keras.layers.add([shortcut, x], name=name+'_add')
    # ReLU activation
    x = tf.keras.layers.ReLU(name=name+'_relu')(x)
    
    return x

# %%
# ResNet

def resnet50(input_shape, num_classes):
    # Input layer
    inputs = tf.keras.layers.Input(shape=input_shape, name='input')
    # Initial convolution layer
    x = conv(inputs, filters=64, kernel_size=7, strides=2, name='conv1')
    # Max pooling layer
    x = tf.keras.layers.MaxPooling2D(pool_size=3, strides=2, padding='same', name='max_pool')(x)

    # Residual blocks
    x = projection(x, filters=64, kernel_size=3, strides=1, name='conv2_block1')
    x = identity(x, filters=64, kernel_size=3, name='conv2_block2')
    x = identity(x, filters=64, kernel_size=3, name='conv2_block3')

    x = projection(x, filters=128, kernel_size=3, strides=2, name='conv3_block1')
    x = identity(x, filters=128, kernel_size=3, name='conv3_block2')
    x = identity(x, filters=128, kernel_size=3, name='conv3_block3')
    x = identity(x, filters=128, kernel_size=3, name='conv3_block4')

    x = projection(x, filters=256, kernel_size=3, strides=2, name='conv4_block1')
    x = identity(x, filters=256, kernel_size=3, name='conv4_block2')
    x = identity(x, filters=256, kernel_size=3, name='conv4_block3')
    x = identity(x, filters=256, kernel_size=3, name='conv4_block4')
    x = identity(x, filters=256, kernel_size=3, name='conv4_block5')
    x = identity(x, filters=256, kernel_size=3, name='conv4_block6')

    x = projection(x, filters=512, kernel_size=3, strides=2, name='conv5_block1')
    x = identity(x, filters=512, kernel_size=3, name='conv5_block2')
    x = identity(x, filters=512, kernel_size=3, name='conv5_block3')

    # Average pooling layer
    x = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')(x)
    
    # Fully connected layer
    x = tf.keras.layers.Dense(units=256, activation='relu', name='fc')(x)
    x = tf.keras.layers.Dense(units=num_classes, activation='softmax', name='fc1')(x)  

    # Create model
    model = tf.keras.models.Model(inputs=inputs, outputs=x, name='resnet50')
    
    return model

# %%
resnet = resnet50(input_shape=(32, 32, 3), num_classes=10)

# %%
# 모델 구조 확인하기
resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input (InputLayer)             [(None, 32, 32, 3)]  0           []
#
#  conv1_conv (Conv2D)            (None, 16, 16, 64)   9472        ['input[0][0]']
#
#  conv1_bn (BatchNormalization)  (None, 16, 16, 64)   256         ['conv1_conv[0][0]']
#
#  conv1_relu (ReLU)              (None, 16, 16, 64)   0           ['conv1_bn[0][0]']
#
#  max_pool (MaxPooling2D)        (None, 8, 8, 64)     0           ['conv1_relu[0][0]']
#
#  conv2_block1_conv1_conv (Conv2  (None, 8, 8, 64)    36928       ['max_pool[0][0]']
#  D)
#
#  conv2_block1_conv1_bn (BatchNo  (None, 8, 8, 64)    256         ['conv2_block1_conv1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_conv1_relu (ReLU)  (None, 8, 8, 64)    0           ['conv2_block1_conv1_bn[0][0]']
#
#  conv2_block1_conv2_conv (Conv2  (None, 8, 8, 64)    36928       ['conv2_block1_conv1_relu[0][0]']
#  D)
#
#  conv2_block1_conv2_bn (BatchNo  (None, 8, 8, 64)    256         ['conv2_block1_conv2_conv[0][0]']
#  rmalization)
#
#  conv2_block1_conv (Conv2D)     (None, 8, 8, 64)     4160        ['max_pool[0][0]']
#
#  conv2_block1_conv2_relu (ReLU)  (None, 8, 8, 64)    0           ['conv2_block1_conv2_bn[0][0]']
#
#  conv2_block1_add (Add)         (None, 8, 8, 64)     0           ['conv2_block1_conv[0][0]',
#                                                                   'conv2_block1_conv2_relu[0][0]']
#
#  conv2_block1_relu (ReLU)       (None, 8, 8, 64)     0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_conv1_conv (Conv2  (None, 8, 8, 64)    36928       ['conv2_block1_relu[0][0]']
#  D)
#
#  conv2_block2_conv1_bn (BatchNo  (None, 8, 8, 64)    256         ['conv2_block2_conv1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_conv1_relu (ReLU)  (None, 8, 8, 64)    0           ['conv2_block2_conv1_bn[0][0]']
#
#  conv2_block2_conv2_conv (Conv2  (None, 8, 8, 64)    36928       ['conv2_block2_conv1_relu[0][0]']
#  D)
#
#  conv2_block2_conv2_bn (BatchNo  (None, 8, 8, 64)    256         ['conv2_block2_conv2_conv[0][0]']
#  rmalization)
#
#  conv2_block2_conv2_relu (ReLU)  (None, 8, 8, 64)    0           ['conv2_block2_conv2_bn[0][0]']
#
#  conv2_block2_add (Add)         (None, 8, 8, 64)     0           ['conv2_block1_relu[0][0]',
#                                                                   'conv2_block2_conv2_relu[0][0]']
#
#  conv2_block2_relu (ReLU)       (None, 8, 8, 64)     0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_conv1_conv (Conv2  (None, 8, 8, 64)    36928       ['conv2_block2_relu[0][0]']
#  D)
#
#  conv2_block3_conv1_bn (BatchNo  (None, 8, 8, 64)    256         ['conv2_block3_conv1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_conv1_relu (ReLU)  (None, 8, 8, 64)    0           ['conv2_block3_conv1_bn[0][0]']
#
#  conv2_block3_conv2_conv (Conv2  (None, 8, 8, 64)    36928       ['conv2_block3_conv1_relu[0][0]']
#  D)
#
#  conv2_block3_conv2_bn (BatchNo  (None, 8, 8, 64)    256         ['conv2_block3_conv2_conv[0][0]']
#  rmalization)
#
#  conv2_block3_conv2_relu (ReLU)  (None, 8, 8, 64)    0           ['conv2_block3_conv2_bn[0][0]']
#
#  conv2_block3_add (Add)         (None, 8, 8, 64)     0           ['conv2_block2_relu[0][0]',
#                                                                   'conv2_block3_conv2_relu[0][0]']
#
#  conv2_block3_relu (ReLU)       (None, 8, 8, 64)     0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_conv1_conv (Conv2  (None, 4, 4, 128)   73856       ['conv2_block3_relu[0][0]']
#  D)
#
#  conv3_block1_conv1_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block1_conv1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_conv1_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block1_conv1_bn[0][0]']
#
#  conv3_block1_conv2_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block1_conv1_relu[0][0]']
#  D)
#
#  conv3_block1_conv2_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block1_conv2_conv[0][0]']
#  rmalization)
#
#  conv3_block1_conv (Conv2D)     (None, 4, 4, 128)    8320        ['conv2_block3_relu[0][0]']
#
#  conv3_block1_conv2_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block1_conv2_bn[0][0]']
#
#  conv3_block1_add (Add)         (None, 4, 4, 128)    0           ['conv3_block1_conv[0][0]',
#                                                                   'conv3_block1_conv2_relu[0][0]']
#
#  conv3_block1_relu (ReLU)       (None, 4, 4, 128)    0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_conv1_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block1_relu[0][0]']
#  D)
#
#  conv3_block2_conv1_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block2_conv1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_conv1_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block2_conv1_bn[0][0]']
#
#  conv3_block2_conv2_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block2_conv1_relu[0][0]']
#  D)
#
#  conv3_block2_conv2_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block2_conv2_conv[0][0]']
#  rmalization)
#
#  conv3_block2_conv2_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block2_conv2_bn[0][0]']
#
#  conv3_block2_add (Add)         (None, 4, 4, 128)    0           ['conv3_block1_relu[0][0]',
#                                                                   'conv3_block2_conv2_relu[0][0]']
#
#  conv3_block2_relu (ReLU)       (None, 4, 4, 128)    0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_conv1_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block2_relu[0][0]']
#  D)
#
#  conv3_block3_conv1_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block3_conv1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_conv1_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block3_conv1_bn[0][0]']
#
#  conv3_block3_conv2_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block3_conv1_relu[0][0]']
#  D)
#
#  conv3_block3_conv2_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block3_conv2_conv[0][0]']
#  rmalization)
#
#  conv3_block3_conv2_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block3_conv2_bn[0][0]']
#
#  conv3_block3_add (Add)         (None, 4, 4, 128)    0           ['conv3_block2_relu[0][0]',
#                                                                   'conv3_block3_conv2_relu[0][0]']
#
#  conv3_block3_relu (ReLU)       (None, 4, 4, 128)    0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_conv1_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block3_relu[0][0]']
#  D)
#
#  conv3_block4_conv1_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block4_conv1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_conv1_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block4_conv1_bn[0][0]']
#
#  conv3_block4_conv2_conv (Conv2  (None, 4, 4, 128)   147584      ['conv3_block4_conv1_relu[0][0]']
#  D)
#
#  conv3_block4_conv2_bn (BatchNo  (None, 4, 4, 128)   512         ['conv3_block4_conv2_conv[0][0]']
#  rmalization)
#
#  conv3_block4_conv2_relu (ReLU)  (None, 4, 4, 128)   0           ['conv3_block4_conv2_bn[0][0]']
#
#  conv3_block4_add (Add)         (None, 4, 4, 128)    0           ['conv3_block3_relu[0][0]',
#                                                                   'conv3_block4_conv2_relu[0][0]']
#
#  conv3_block4_relu (ReLU)       (None, 4, 4, 128)    0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_conv1_conv (Conv2  (None, 2, 2, 256)   295168      ['conv3_block4_relu[0][0]']
#  D)
#
#  conv4_block1_conv1_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block1_conv1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_conv1_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block1_conv1_bn[0][0]']
#
#  conv4_block1_conv2_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block1_conv1_relu[0][0]']
#  D)
#
#  conv4_block1_conv2_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block1_conv2_conv[0][0]']
#  rmalization)
#
#  conv4_block1_conv (Conv2D)     (None, 2, 2, 256)    33024       ['conv3_block4_relu[0][0]']
#
#  conv4_block1_conv2_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block1_conv2_bn[0][0]']
#
#  conv4_block1_add (Add)         (None, 2, 2, 256)    0           ['conv4_block1_conv[0][0]',
#                                                                   'conv4_block1_conv2_relu[0][0]']
#
#  conv4_block1_relu (ReLU)       (None, 2, 2, 256)    0           ['conv4_block1_add[0][0]']
#
#  conv4_block2_conv1_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block1_relu[0][0]']
#  D)
#
#  conv4_block2_conv1_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block2_conv1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_conv1_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block2_conv1_bn[0][0]']
#
#  conv4_block2_conv2_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block2_conv1_relu[0][0]']
#  D)
#
#  conv4_block2_conv2_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block2_conv2_conv[0][0]']
#  rmalization)
#
#  conv4_block2_conv2_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block2_conv2_bn[0][0]']
#
#  conv4_block2_add (Add)         (None, 2, 2, 256)    0           ['conv4_block1_relu[0][0]',
#                                                                   'conv4_block2_conv2_relu[0][0]']
#
#  conv4_block2_relu (ReLU)       (None, 2, 2, 256)    0           ['conv4_block2_add[0][0]']
#
#  conv4_block3_conv1_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block2_relu[0][0]']
#  D)
#
#  conv4_block3_conv1_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block3_conv1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_conv1_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block3_conv1_bn[0][0]']
#
#  conv4_block3_conv2_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block3_conv1_relu[0][0]']
#  D)
#
#  conv4_block3_conv2_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block3_conv2_conv[0][0]']
#  rmalization)
#
#  conv4_block3_conv2_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block3_conv2_bn[0][0]']
#
#  conv4_block3_add (Add)         (None, 2, 2, 256)    0           ['conv4_block2_relu[0][0]',
#                                                                   'conv4_block3_conv2_relu[0][0]']
#
#  conv4_block3_relu (ReLU)       (None, 2, 2, 256)    0           ['conv4_block3_add[0][0]']
#
#  conv4_block4_conv1_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block3_relu[0][0]']
#  D)
#
#  conv4_block4_conv1_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block4_conv1_conv[0][0]']
#  rmalization)
#
#  conv4_block4_conv1_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block4_conv1_bn[0][0]']
#
#  conv4_block4_conv2_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block4_conv1_relu[0][0]']
#  D)
#
#  conv4_block4_conv2_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block4_conv2_conv[0][0]']
#  rmalization)
#
#  conv4_block4_conv2_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block4_conv2_bn[0][0]']
#
#  conv4_block4_add (Add)         (None, 2, 2, 256)    0           ['conv4_block3_relu[0][0]',
#                                                                   'conv4_block4_conv2_relu[0][0]']
#
#  conv4_block4_relu (ReLU)       (None, 2, 2, 256)    0           ['conv4_block4_add[0][0]']
#
#  conv4_block5_conv1_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block4_relu[0][0]']
#  D)
#
#  conv4_block5_conv1_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block5_conv1_conv[0][0]']
#  rmalization)
#
#  conv4_block5_conv1_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block5_conv1_bn[0][0]']
#
#  conv4_block5_conv2_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block5_conv1_relu[0][0]']
#  D)
#
#  conv4_block5_conv2_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block5_conv2_conv[0][0]']
#  rmalization)
#
#  conv4_block5_conv2_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block5_conv2_bn[0][0]']
#
#  conv4_block5_add (Add)         (None, 2, 2, 256)    0           ['conv4_block4_relu[0][0]',
#                                                                   'conv4_block5_conv2_relu[0][0]']
#
#  conv4_block5_relu (ReLU)       (None, 2, 2, 256)    0           ['conv4_block5_add[0][0]']
#
#  conv4_block6_conv1_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block5_relu[0][0]']
#  D)
#
#  conv4_block6_conv1_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block6_conv1_conv[0][0]']
#  rmalization)
#
#  conv4_block6_conv1_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block6_conv1_bn[0][0]']
#
#  conv4_block6_conv2_conv (Conv2  (None, 2, 2, 256)   590080      ['conv4_block6_conv1_relu[0][0]']
#  D)
#
#  conv4_block6_conv2_bn (BatchNo  (None, 2, 2, 256)   1024        ['conv4_block6_conv2_conv[0][0]']
#  rmalization)
#
#  conv4_block6_conv2_relu (ReLU)  (None, 2, 2, 256)   0           ['conv4_block6_conv2_bn[0][0]']
#
#  conv4_block6_add (Add)         (None, 2, 2, 256)    0           ['conv4_block5_relu[0][0]',
#                                                                   'conv4_block6_conv2_relu[0][0]']
#
#  conv4_block6_relu (ReLU)       (None, 2, 2, 256)    0           ['conv4_block6_add[0][0]']
#
#  conv5_block1_conv1_conv (Conv2  (None, 1, 1, 512)   1180160     ['conv4_block6_relu[0][0]']
#  D)
#
#  conv5_block1_conv1_bn (BatchNo  (None, 1, 1, 512)   2048        ['conv5_block1_conv1_conv[0][0]']
#  rmalization)
#
#  conv5_block1_conv1_relu (ReLU)  (None, 1, 1, 512)   0           ['conv5_block1_conv1_bn[0][0]']
#
#  conv5_block1_conv2_conv (Conv2  (None, 1, 1, 512)   2359808     ['conv5_block1_conv1_relu[0][0]']
#  D)
#
#  conv5_block1_conv2_bn (BatchNo  (None, 1, 1, 512)   2048        ['conv5_block1_conv2_conv[0][0]']
#  rmalization)
#
#  conv5_block1_conv (Conv2D)     (None, 1, 1, 512)    131584      ['conv4_block6_relu[0][0]']
#
#  conv5_block1_conv2_relu (ReLU)  (None, 1, 1, 512)   0           ['conv5_block1_conv2_bn[0][0]']
#
#  conv5_block1_add (Add)         (None, 1, 1, 512)    0           ['conv5_block1_conv[0][0]',
#                                                                   'conv5_block1_conv2_relu[0][0]']
#
#  conv5_block1_relu (ReLU)       (None, 1, 1, 512)    0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_conv1_conv (Conv2  (None, 1, 1, 512)   2359808     ['conv5_block1_relu[0][0]']
#  D)
#
#  conv5_block2_conv1_bn (BatchNo  (None, 1, 1, 512)   2048        ['conv5_block2_conv1_conv[0][0]']
#  rmalization)
#
#  conv5_block2_conv1_relu (ReLU)  (None, 1, 1, 512)   0           ['conv5_block2_conv1_bn[0][0]']
#
#  conv5_block2_conv2_conv (Conv2  (None, 1, 1, 512)   2359808     ['conv5_block2_conv1_relu[0][0]']
#  D)
#
#  conv5_block2_conv2_bn (BatchNo  (None, 1, 1, 512)   2048        ['conv5_block2_conv2_conv[0][0]']
#  rmalization)
#
#  conv5_block2_conv2_relu (ReLU)  (None, 1, 1, 512)   0           ['conv5_block2_conv2_bn[0][0]']
#
#  conv5_block2_add (Add)         (None, 1, 1, 512)    0           ['conv5_block1_relu[0][0]',
#                                                                   'conv5_block2_conv2_relu[0][0]']
#
#  conv5_block2_relu (ReLU)       (None, 1, 1, 512)    0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_conv1_conv (Conv2  (None, 1, 1, 512)   2359808     ['conv5_block2_relu[0][0]']
#  D)
#
#  conv5_block3_conv1_bn (BatchNo  (None, 1, 1, 512)   2048        ['conv5_block3_conv1_conv[0][0]']
#  rmalization)
#
#  conv5_block3_conv1_relu (ReLU)  (None, 1, 1, 512)   0           ['conv5_block3_conv1_bn[0][0]']
#
#  conv5_block3_conv2_conv (Conv2  (None, 1, 1, 512)   2359808     ['conv5_block3_conv1_relu[0][0]']
#  D)
#
#  conv5_block3_conv2_bn (BatchNo  (None, 1, 1, 512)   2048        ['conv5_block3_conv2_conv[0][0]']
#  rmalization)
#
#  conv5_block3_conv2_relu (ReLU)  (None, 1, 1, 512)   0           ['conv5_block3_conv2_bn[0][0]']
#
#  conv5_block3_add (Add)         (None, 1, 1, 512)    0           ['conv5_block2_relu[0][0]',
#                                                                   'conv5_block3_conv2_relu[0][0]']
#
#  conv5_block3_relu (ReLU)       (None, 1, 1, 512)    0           ['conv5_block3_add[0][0]']
#
#  avg_pool (GlobalAveragePooling  (None, 512)         0           ['conv5_block3_relu[0][0]']
#  2D)
#
#  fc (Dense)                     (None, 256)          131328      ['avg_pool[0][0]']
#
#  fc1 (Dense)                    (None, 10)           2570        ['fc[0][0]']
#
# ==================================================================================================
# Total params: 21,444,682
# Trainable params: 21,429,450
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
# 새로운 모델 생성하기
model = keras.models.Sequential()

# ResNet50 모델 추가하기
model.add(resnet)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from google.colab import drive

drive.mount('/content/gdrive')

filepath = '/content/gdrive/My Drive/project/newepoch/model.{epoch:02d}.hdf5'
modelckpt = ModelCheckpoint(filepath=filepath)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
model.compile(optimizer=Adam(learning_rate=0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=128, validation_data=(x_test, y_test),callbacks=[modelckpt])
# Out:
# Epoch 1/100
# 391/391 [==============================] - 47s 55ms/step - loss: 0.9564 - accuracy: 0.6688 - val_loss: 1.5819 - val_accuracy: 0.5165
# Epoch 2/100
# 391/391 [==============================] - 20s 52ms/step - loss: 0.7988 - accuracy: 0.7233 - val_loss: 1.3889 - val_accuracy: 0.5582
# Epoch 3/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.6784 - accuracy: 0.7636 - val_loss: 0.8787 - val_accuracy: 0.7006
# Epoch 4/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.5884 - accuracy: 0.7966 - val_loss: 1.2946 - val_accuracy: 0.5917
# Epoch 5/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.5057 - accuracy: 0.8263 - val_loss: 1.1347 - val_accuracy: 0.6632
# Epoch 6/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.4451 - accuracy: 0.8446 - val_loss: 1.0676 - val_accuracy: 0.6768
# Epoch 7/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.3740 - accuracy: 0.8707 - val_loss: 0.9719 - val_accuracy: 0.7029
# Epoch 8/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.3122 - accuracy: 0.8918 - val_loss: 0.9387 - val_accuracy: 0.7265
# Epoch 9/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.2649 - accuracy: 0.9078 - val_loss: 1.1239 - val_accuracy: 0.6976
# Epoch 10/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.2582 - accuracy: 0.9128 - val_loss: 1.1176 - val_accuracy: 0.6994
# Epoch 11/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.1938 - accuracy: 0.9330 - val_loss: 1.1439 - val_accuracy: 0.7086
# Epoch 12/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.1594 - accuracy: 0.9447 - val_loss: 1.3132 - val_accuracy: 0.6890
# Epoch 13/100
# 391/391 [==============================] - 20s 52ms/step - loss: 0.1424 - accuracy: 0.9510 - val_loss: 1.4209 - val_accuracy: 0.6741
# Epoch 14/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.1268 - accuracy: 0.9566 - val_loss: 1.1757 - val_accuracy: 0.7243
# Epoch 15/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.1076 - accuracy: 0.9637 - val_loss: 1.1487 - val_accuracy: 0.7375
# Epoch 16/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.1036 - accuracy: 0.9641 - val_loss: 1.4279 - val_accuracy: 0.7014
# Epoch 17/100
# 391/391 [==============================] - 20s 52ms/step - loss: 0.1006 - accuracy: 0.9660 - val_loss: 1.1991 - val_accuracy: 0.7354
# Epoch 18/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0845 - accuracy: 0.9711 - val_loss: 1.3810 - val_accuracy: 0.7194
# Epoch 19/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0819 - accuracy: 0.9722 - val_loss: 1.2429 - val_accuracy: 0.7365
# Epoch 20/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0787 - accuracy: 0.9733 - val_loss: 1.2199 - val_accuracy: 0.7464
# Epoch 21/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0754 - accuracy: 0.9742 - val_loss: 1.3044 - val_accuracy: 0.7233
# Epoch 22/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0692 - accuracy: 0.9759 - val_loss: 1.5307 - val_accuracy: 0.6812
# Epoch 23/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0667 - accuracy: 0.9775 - val_loss: 1.3779 - val_accuracy: 0.7378
# Epoch 24/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0640 - accuracy: 0.9771 - val_loss: 1.3897 - val_accuracy: 0.7309
# Epoch 25/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0577 - accuracy: 0.9806 - val_loss: 1.3883 - val_accuracy: 0.7428
# Epoch 26/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0607 - accuracy: 0.9796 - val_loss: 1.2522 - val_accuracy: 0.7558
# Epoch 27/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0565 - accuracy: 0.9805 - val_loss: 1.2810 - val_accuracy: 0.7533
# Epoch 28/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0576 - accuracy: 0.9801 - val_loss: 1.4120 - val_accuracy: 0.7296
# Epoch 29/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0549 - accuracy: 0.9821 - val_loss: 1.3863 - val_accuracy: 0.7381
# Epoch 30/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0478 - accuracy: 0.9837 - val_loss: 1.4095 - val_accuracy: 0.7313
# Epoch 31/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0574 - accuracy: 0.9806 - val_loss: 1.4343 - val_accuracy: 0.7364
# Epoch 32/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0489 - accuracy: 0.9837 - val_loss: 1.4500 - val_accuracy: 0.7217
# Epoch 33/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0446 - accuracy: 0.9849 - val_loss: 1.4630 - val_accuracy: 0.7322
# Epoch 34/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0576 - accuracy: 0.9810 - val_loss: 1.3785 - val_accuracy: 0.7444
# Epoch 35/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0532 - accuracy: 0.9826 - val_loss: 1.3862 - val_accuracy: 0.7441
# Epoch 36/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0355 - accuracy: 0.9881 - val_loss: 1.5177 - val_accuracy: 0.7331
# Epoch 37/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0407 - accuracy: 0.9867 - val_loss: 1.4124 - val_accuracy: 0.7496
# Epoch 38/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0418 - accuracy: 0.9859 - val_loss: 1.3837 - val_accuracy: 0.7442
# Epoch 39/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0429 - accuracy: 0.9852 - val_loss: 1.5456 - val_accuracy: 0.7315
# Epoch 40/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0390 - accuracy: 0.9871 - val_loss: 1.8527 - val_accuracy: 0.7171
# Epoch 41/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0434 - accuracy: 0.9862 - val_loss: 1.3953 - val_accuracy: 0.7444
# Epoch 42/100
# 391/391 [==============================] - 25s 63ms/step - loss: 0.0411 - accuracy: 0.9861 - val_loss: 1.5459 - val_accuracy: 0.7300
# Epoch 43/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0346 - accuracy: 0.9883 - val_loss: 1.5946 - val_accuracy: 0.7211
# Epoch 44/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0319 - accuracy: 0.9895 - val_loss: 1.5365 - val_accuracy: 0.7410
# Epoch 45/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0389 - accuracy: 0.9869 - val_loss: 1.5579 - val_accuracy: 0.7237
# Epoch 46/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 1.4305 - val_accuracy: 0.7381
# Epoch 47/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0343 - accuracy: 0.9884 - val_loss: 1.5977 - val_accuracy: 0.7384
# Epoch 48/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0327 - accuracy: 0.9889 - val_loss: 1.5361 - val_accuracy: 0.7394
# Epoch 49/100
# 391/391 [==============================] - 26s 66ms/step - loss: 0.0312 - accuracy: 0.9897 - val_loss: 1.4038 - val_accuracy: 0.7520
# Epoch 50/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0330 - accuracy: 0.9889 - val_loss: 1.5195 - val_accuracy: 0.7412
# Epoch 51/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0358 - accuracy: 0.9882 - val_loss: 1.4985 - val_accuracy: 0.7453
# Epoch 52/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0314 - accuracy: 0.9900 - val_loss: 1.4641 - val_accuracy: 0.7537
# Epoch 53/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0332 - accuracy: 0.9898 - val_loss: 1.3561 - val_accuracy: 0.7405
# Epoch 54/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0294 - accuracy: 0.9905 - val_loss: 1.6827 - val_accuracy: 0.7387
# Epoch 55/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0310 - accuracy: 0.9901 - val_loss: 1.6678 - val_accuracy: 0.7262
# Epoch 56/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.0302 - accuracy: 0.9891 - val_loss: 1.6543 - val_accuracy: 0.7454
# Epoch 57/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0339 - accuracy: 0.9892 - val_loss: 1.4697 - val_accuracy: 0.7353
# Epoch 58/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.1111 - accuracy: 0.9650 - val_loss: 1.2788 - val_accuracy: 0.7468
# Epoch 59/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0381 - accuracy: 0.9880 - val_loss: 1.6310 - val_accuracy: 0.7578
# Epoch 60/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 1.6322 - val_accuracy: 0.7503
# Epoch 61/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0178 - accuracy: 0.9945 - val_loss: 1.7560 - val_accuracy: 0.7491
# Epoch 62/100
# 391/391 [==============================] - 25s 64ms/step - loss: 0.0201 - accuracy: 0.9937 - val_loss: 1.4793 - val_accuracy: 0.7625
# Epoch 63/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0229 - accuracy: 0.9923 - val_loss: 1.6358 - val_accuracy: 0.7455
# Epoch 64/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0243 - accuracy: 0.9915 - val_loss: 1.8452 - val_accuracy: 0.7021
# Epoch 65/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0265 - accuracy: 0.9910 - val_loss: 1.6285 - val_accuracy: 0.7477
# Epoch 66/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0275 - accuracy: 0.9905 - val_loss: 1.6519 - val_accuracy: 0.7375
# Epoch 67/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0202 - accuracy: 0.9928 - val_loss: 1.6168 - val_accuracy: 0.7511
# Epoch 68/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 1.6622 - val_accuracy: 0.7258
# Epoch 69/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.0265 - accuracy: 0.9910 - val_loss: 1.5705 - val_accuracy: 0.7580
# Epoch 70/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 1.8088 - val_accuracy: 0.7252
# Epoch 71/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0264 - accuracy: 0.9915 - val_loss: 1.5259 - val_accuracy: 0.7593
# Epoch 72/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0204 - accuracy: 0.9934 - val_loss: 1.6459 - val_accuracy: 0.7632
# Epoch 73/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0252 - accuracy: 0.9920 - val_loss: 1.5544 - val_accuracy: 0.7512
# Epoch 74/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0232 - accuracy: 0.9924 - val_loss: 1.5804 - val_accuracy: 0.7546
# Epoch 75/100
# 391/391 [==============================] - 20s 52ms/step - loss: 0.0227 - accuracy: 0.9926 - val_loss: 1.7568 - val_accuracy: 0.7434
# Epoch 76/100
# 391/391 [==============================] - 24s 61ms/step - loss: 0.0230 - accuracy: 0.9927 - val_loss: 1.7354 - val_accuracy: 0.7330
# Epoch 77/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0198 - accuracy: 0.9935 - val_loss: 1.8430 - val_accuracy: 0.7381
# Epoch 78/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0250 - accuracy: 0.9921 - val_loss: 1.8723 - val_accuracy: 0.7302
# Epoch 79/100
# 391/391 [==============================] - 19s 49ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 1.4793 - val_accuracy: 0.7694
# Epoch 80/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0189 - accuracy: 0.9941 - val_loss: 1.7433 - val_accuracy: 0.7454
# Epoch 81/100
# 391/391 [==============================] - 19s 48ms/step - loss: 0.0261 - accuracy: 0.9922 - val_loss: 1.8145 - val_accuracy: 0.7321
# Epoch 82/100
# 391/391 [==============================] - 24s 62ms/step - loss: 0.0230 - accuracy: 0.9923 - val_loss: 1.5230 - val_accuracy: 0.7591
# Epoch 83/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0175 - accuracy: 0.9943 - val_loss: 1.6736 - val_accuracy: 0.7661
# Epoch 84/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 1.6988 - val_accuracy: 0.7472
# Epoch 85/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0241 - accuracy: 0.9918 - val_loss: 1.5624 - val_accuracy: 0.7532
# Epoch 86/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0169 - accuracy: 0.9947 - val_loss: 1.6661 - val_accuracy: 0.7577
# Epoch 87/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0206 - accuracy: 0.9934 - val_loss: 1.6093 - val_accuracy: 0.7425
# Epoch 88/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0206 - accuracy: 0.9933 - val_loss: 1.7908 - val_accuracy: 0.7588
# Epoch 89/100
# 391/391 [==============================] - 25s 63ms/step - loss: 0.0193 - accuracy: 0.9936 - val_loss: 1.5782 - val_accuracy: 0.7628
# Epoch 90/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0220 - accuracy: 0.9931 - val_loss: 2.1646 - val_accuracy: 0.6899
# Epoch 91/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0223 - accuracy: 0.9928 - val_loss: 1.4695 - val_accuracy: 0.7527
# Epoch 92/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 1.7517 - val_accuracy: 0.7555
# Epoch 93/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0176 - accuracy: 0.9943 - val_loss: 1.5587 - val_accuracy: 0.7585
# Epoch 94/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 1.6407 - val_accuracy: 0.7602
# Epoch 95/100
# 391/391 [==============================] - 23s 60ms/step - loss: 0.0209 - accuracy: 0.9936 - val_loss: 1.5856 - val_accuracy: 0.7599
# Epoch 96/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 1.5531 - val_accuracy: 0.7562
# Epoch 97/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0192 - accuracy: 0.9941 - val_loss: 1.6642 - val_accuracy: 0.7561
# Epoch 98/100
# 391/391 [==============================] - 20s 50ms/step - loss: 0.0206 - accuracy: 0.9932 - val_loss: 2.1618 - val_accuracy: 0.7347
# Epoch 99/100
# 391/391 [==============================] - 19s 50ms/step - loss: 0.0203 - accuracy: 0.9935 - val_loss: 1.5594 - val_accuracy: 0.7500
# Epoch 100/100
# 391/391 [==============================] - 20s 51ms/step - loss: 0.0182 - accuracy: 0.9944 - val_loss: 1.7247 - val_accuracy: 0.7437

# %%
#저장
model.save('/content/gdrive/My Drive/project/finish/new/modelss.hdf5')

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy:', test_acc)
# Out:
# Test accuracy: 0.7437000274658203

# %%
import matplotlib.pyplot as plt

# 학습 과정에서 계산한 정확도와 손실을 변수로 저장
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
# 정확도 그래프
plt.plot(acc)
plt.plot(val_acc)
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# 손실 그래프
plt.plot(loss)
plt.plot(val_loss)
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
